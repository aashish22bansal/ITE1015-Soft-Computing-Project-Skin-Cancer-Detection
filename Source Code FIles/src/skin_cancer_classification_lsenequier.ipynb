# %%
#import pictures from drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/My Drive/Data/skin-cancer-malignant-vs-benign.zip" -d "/content/drive/My Drive/Data"

# %%
#Upgrade memory - high RAM run time
#a = []
#while(1):
   # a.append(‘1’)

# %%
#Import some necessary Modules
import os
import cv2
import keras
import numpy as np
import pandas as pd
import random as rn
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
from IPython.display import SVG
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
#loading pictures 
def Dataset_loader(DIR,RESIZE):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
            img = cv2.resize(img, (RESIZE,RESIZE))
            IMG.append(np.array(img)/255.)
    return IMG

benign_train = np.array(Dataset_loader('/content/drive/My Drive/Data/train/benign',224))
malign_train = np.array(Dataset_loader('/content/drive/My Drive/Data/train/malignant',224))
benign_test = np.array(Dataset_loader('/content/drive/My Drive/Data/test/benign',224))
malign_test = np.array(Dataset_loader('/content/drive/My Drive/Data/test/malignant',224))
# Out:
# 100%|██████████| 1440/1440 [06:52<00:00,  3.49it/s]
# 100%|██████████| 1197/1197 [06:00<00:00,  3.32it/s]
# 100%|██████████| 360/360 [01:40<00:00,  3.59it/s]
# 100%|██████████| 300/300 [01:23<00:00,  3.58it/s]

# %%
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# Split validation data from train data
x_train=X_train[500:]
x_val=X_train[:500]
y_train=Y_train[500:]
y_val=Y_train[:500]

# %%
X_test.shape, x_val.shape, x_train.shape
# Out:
# ((660, 224, 224, 3), (500, 224, 224, 3), (2137, 224, 224, 3))

# %%
# Display first 20 images of moles

fig=plt.figure(figsize=(10, 10))

for i in range(1, 20 +1):
    ax = fig.add_subplot(4, 5, i)
    if Y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %%
# one hot encoding 
from keras.utils.np_utils import to_categorical # used for converting labels to one-hot-encodin
y_train = to_categorical(y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
y_val = to_categorical(y_val, num_classes= 2)

# %%
# normalization 
x_train = x_train/255.
X_test = X_test/255.
x_val = x_val/255.

# %%
X_test.shape, x_val.shape, x_train.shape
# Out:
# ((660, 224, 224, 3), (500, 224, 224, 3), (2137, 224, 224, 3))

# %%
# data augmentation - cut out 

import numpy as np

def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# data augmentation 

from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=45,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
        preprocessing_function=get_random_eraser(p=0.5, v_h=0, s_h=0.25))

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import datasets
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
# building the model 

# !pip install -U efficientnet
from keras import layers
import efficientnet.keras as efn
from keras import regularizers 

eff_net = efn.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
model=Sequential()
model.add(eff_net)
model.add(layers.GlobalAveragePooling2D())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Dense(2, activation='softmax'))

alpha = 1e-3  # weight decay coefficient
for layer in model.layers:
    if isinstance(layer, keras.layers.Conv2D) or isinstance(layer, keras.layers.Dense):
        layer.add_loss(keras.regularizers.l2(alpha)(layer.kernel))
    if hasattr(layer, 'bias_regularizer') and layer.use_bias:
        layer.add_loss(keras.regularizers.l2(alpha)(layer.bias))

model.summary()
# Out:
# Collecting efficientnet
#   Downloading https://files.pythonhosted.org/packages/28/91/67848a143b54c331605bfba5fd31cf4e9db13d2e429d103fe807acc3bcf4/efficientnet-1.1.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet) (0.16.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.18.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.10.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (1.1.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (2.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (3.2.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (7.0.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (2.4)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.12.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (1.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.4.7)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet) (4.4.2)
# Installing collected packages: efficientnet
# Successfully installed efficientnet-1.1.0
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16809984/16804768 [==============================] - 0s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Model)      (None, 7, 7, 1280)        4049564
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               163968
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 4,214,302
# Trainable params: 4,172,030
# Non-trainable params: 42,272
# _________________________________________________________________

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# callback - if accuracy doesn't improve after 3 epoch then reduce lr by factor 0.5 
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,patience=3, min_lr=0.000005)

# %%
# train the model 
optimizer=optimizers.Adam(lr=0.001)
model.compile(optimizer=optimizer,loss="binary_crossentropy", metrics=['accuracy'])
h = model.fit_generator(datagen.flow(x_train,y_train, batch_size=64),epochs=100, validation_data=[x_val, y_val],callbacks=[reduce_lr])
# Out:
# Epoch 1/100
# 34/34 [==============================] - 79s 2s/step - loss: 0.2507 - accuracy: 0.8854 - val_loss: 3.4093 - val_accuracy: 0.5380
# Epoch 2/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.2344 - accuracy: 0.8956 - val_loss: 2.1071 - val_accuracy: 0.5380
# Epoch 3/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.1976 - accuracy: 0.9162 - val_loss: 2.0671 - val_accuracy: 0.5380
# Epoch 4/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.1956 - accuracy: 0.9223 - val_loss: 0.7149 - val_accuracy: 0.5620
# Epoch 5/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.1953 - accuracy: 0.9144 - val_loss: 2.1966 - val_accuracy: 0.5400
# Epoch 6/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.1781 - accuracy: 0.9209 - val_loss: 1.3574 - val_accuracy: 0.5860
# Epoch 7/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.1997 - accuracy: 0.9204 - val_loss: 0.6524 - val_accuracy: 0.7960
# Epoch 8/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.1425 - accuracy: 0.9476 - val_loss: 1.8357 - val_accuracy: 0.6300
# Epoch 9/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.1545 - accuracy: 0.9275 - val_loss: 3.0302 - val_accuracy: 0.5500
# Epoch 10/100
# 34/34 [==============================] - 57s 2s/step - loss: 0.1492 - accuracy: 0.9387 - val_loss: 2.2583 - val_accuracy: 0.5780
# Epoch 11/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.1132 - accuracy: 0.9560 - val_loss: 1.9813 - val_accuracy: 0.6120
# Epoch 12/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0903 - accuracy: 0.9640 - val_loss: 1.6532 - val_accuracy: 0.6640
# Epoch 13/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0888 - accuracy: 0.9658 - val_loss: 1.0447 - val_accuracy: 0.7340
# Epoch 14/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0678 - accuracy: 0.9761 - val_loss: 0.8008 - val_accuracy: 0.7660
# Epoch 15/100
# 34/34 [==============================] - 57s 2s/step - loss: 0.0551 - accuracy: 0.9789 - val_loss: 0.7467 - val_accuracy: 0.8000
# Epoch 16/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0665 - accuracy: 0.9771 - val_loss: 0.5512 - val_accuracy: 0.8460
# Epoch 17/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0588 - accuracy: 0.9780 - val_loss: 0.5745 - val_accuracy: 0.8360
# Epoch 18/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0542 - accuracy: 0.9832 - val_loss: 0.5456 - val_accuracy: 0.8280
# Epoch 19/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0544 - accuracy: 0.9818 - val_loss: 0.5875 - val_accuracy: 0.8440
# Epoch 20/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0539 - accuracy: 0.9780 - val_loss: 0.4293 - val_accuracy: 0.8760
# Epoch 21/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0429 - accuracy: 0.9850 - val_loss: 0.4900 - val_accuracy: 0.8640
# Epoch 22/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0390 - accuracy: 0.9855 - val_loss: 0.3973 - val_accuracy: 0.8780
# Epoch 23/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0376 - accuracy: 0.9860 - val_loss: 0.4141 - val_accuracy: 0.8900
# Epoch 24/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0369 - accuracy: 0.9855 - val_loss: 0.3549 - val_accuracy: 0.8940
# Epoch 25/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0333 - accuracy: 0.9888 - val_loss: 0.3651 - val_accuracy: 0.8960
# Epoch 26/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0325 - accuracy: 0.9892 - val_loss: 0.3547 - val_accuracy: 0.9080
# Epoch 27/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0366 - accuracy: 0.9874 - val_loss: 0.3488 - val_accuracy: 0.9060
# Epoch 28/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0284 - accuracy: 0.9897 - val_loss: 0.3750 - val_accuracy: 0.9000
# Epoch 29/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0302 - accuracy: 0.9878 - val_loss: 0.3520 - val_accuracy: 0.9040
# Epoch 30/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0307 - accuracy: 0.9911 - val_loss: 0.3558 - val_accuracy: 0.9020
# Epoch 31/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0281 - accuracy: 0.9906 - val_loss: 0.3911 - val_accuracy: 0.9040
# Epoch 32/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0380 - accuracy: 0.9878 - val_loss: 0.3949 - val_accuracy: 0.9060
# Epoch 33/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0306 - accuracy: 0.9897 - val_loss: 0.3885 - val_accuracy: 0.9020
# Epoch 34/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0315 - accuracy: 0.9892 - val_loss: 0.3788 - val_accuracy: 0.8980
# Epoch 35/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0191 - accuracy: 0.9963 - val_loss: 0.3722 - val_accuracy: 0.9040
# Epoch 36/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0333 - accuracy: 0.9883 - val_loss: 0.3710 - val_accuracy: 0.9040
# Epoch 37/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 0.3692 - val_accuracy: 0.9040
# Epoch 38/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0238 - accuracy: 0.9911 - val_loss: 0.3704 - val_accuracy: 0.9060
# Epoch 39/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.3707 - val_accuracy: 0.9060
# Epoch 40/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.3682 - val_accuracy: 0.9040
# Epoch 41/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0238 - accuracy: 0.9925 - val_loss: 0.3688 - val_accuracy: 0.9060
# Epoch 42/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0167 - accuracy: 0.9939 - val_loss: 0.3716 - val_accuracy: 0.9040
# Epoch 43/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0272 - accuracy: 0.9930 - val_loss: 0.3723 - val_accuracy: 0.9040
# Epoch 44/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0275 - accuracy: 0.9897 - val_loss: 0.3719 - val_accuracy: 0.9040
# Epoch 45/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0258 - accuracy: 0.9911 - val_loss: 0.3725 - val_accuracy: 0.9040
# Epoch 46/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.3748 - val_accuracy: 0.9060
# Epoch 47/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0378 - accuracy: 0.9864 - val_loss: 0.3772 - val_accuracy: 0.9040
# Epoch 48/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.3770 - val_accuracy: 0.9040
# Epoch 49/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0303 - accuracy: 0.9906 - val_loss: 0.3767 - val_accuracy: 0.9040
# Epoch 50/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0197 - accuracy: 0.9920 - val_loss: 0.3739 - val_accuracy: 0.9040
# Epoch 51/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0194 - accuracy: 0.9925 - val_loss: 0.3736 - val_accuracy: 0.9040
# Epoch 52/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0297 - accuracy: 0.9906 - val_loss: 0.3722 - val_accuracy: 0.9040
# Epoch 53/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0250 - accuracy: 0.9925 - val_loss: 0.3716 - val_accuracy: 0.9040
# Epoch 54/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 0.3730 - val_accuracy: 0.9060
# Epoch 55/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0180 - accuracy: 0.9949 - val_loss: 0.3753 - val_accuracy: 0.9060
# Epoch 56/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.3729 - val_accuracy: 0.9060
# Epoch 57/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.3723 - val_accuracy: 0.9060
# Epoch 58/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0215 - accuracy: 0.9930 - val_loss: 0.3737 - val_accuracy: 0.9060
# Epoch 59/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.3731 - val_accuracy: 0.9060
# Epoch 60/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0171 - accuracy: 0.9958 - val_loss: 0.3737 - val_accuracy: 0.9060
# Epoch 61/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0245 - accuracy: 0.9911 - val_loss: 0.3753 - val_accuracy: 0.9080
# Epoch 62/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0208 - accuracy: 0.9925 - val_loss: 0.3751 - val_accuracy: 0.9060
# Epoch 63/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0420 - accuracy: 0.9888 - val_loss: 0.3756 - val_accuracy: 0.9040
# Epoch 64/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.3774 - val_accuracy: 0.9020
# Epoch 65/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0253 - accuracy: 0.9916 - val_loss: 0.3771 - val_accuracy: 0.9020
# Epoch 66/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.3775 - val_accuracy: 0.9020
# Epoch 67/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0229 - accuracy: 0.9930 - val_loss: 0.3759 - val_accuracy: 0.9040
# Epoch 68/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0292 - accuracy: 0.9916 - val_loss: 0.3774 - val_accuracy: 0.9060
# Epoch 69/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 0.3772 - val_accuracy: 0.9040
# Epoch 70/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0147 - accuracy: 0.9963 - val_loss: 0.3765 - val_accuracy: 0.9040
# Epoch 71/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0207 - accuracy: 0.9939 - val_loss: 0.3778 - val_accuracy: 0.9000
# Epoch 72/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0201 - accuracy: 0.9925 - val_loss: 0.3784 - val_accuracy: 0.9060
# Epoch 73/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0217 - accuracy: 0.9920 - val_loss: 0.3829 - val_accuracy: 0.9040
# Epoch 74/100
# 34/34 [==============================] - 57s 2s/step - loss: 0.0200 - accuracy: 0.9920 - val_loss: 0.3807 - val_accuracy: 0.9040
# Epoch 75/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0228 - accuracy: 0.9925 - val_loss: 0.3778 - val_accuracy: 0.9020
# Epoch 76/100
# 34/34 [==============================] - 57s 2s/step - loss: 0.0282 - accuracy: 0.9920 - val_loss: 0.3765 - val_accuracy: 0.9020
# Epoch 77/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0192 - accuracy: 0.9949 - val_loss: 0.3767 - val_accuracy: 0.9020
# Epoch 78/100
# 34/34 [==============================] - 57s 2s/step - loss: 0.0249 - accuracy: 0.9911 - val_loss: 0.3785 - val_accuracy: 0.9040
# Epoch 79/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0255 - accuracy: 0.9934 - val_loss: 0.3812 - val_accuracy: 0.9040
# Epoch 80/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0275 - accuracy: 0.9939 - val_loss: 0.3807 - val_accuracy: 0.9040
# Epoch 81/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0214 - accuracy: 0.9925 - val_loss: 0.3823 - val_accuracy: 0.9040
# Epoch 82/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0248 - accuracy: 0.9906 - val_loss: 0.3817 - val_accuracy: 0.9020
# Epoch 83/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0171 - accuracy: 0.9934 - val_loss: 0.3812 - val_accuracy: 0.9020
# Epoch 84/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0255 - accuracy: 0.9925 - val_loss: 0.3823 - val_accuracy: 0.9040
# Epoch 85/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0192 - accuracy: 0.9939 - val_loss: 0.3812 - val_accuracy: 0.9020
# Epoch 86/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0257 - accuracy: 0.9902 - val_loss: 0.3818 - val_accuracy: 0.9040
# Epoch 87/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0269 - accuracy: 0.9906 - val_loss: 0.3837 - val_accuracy: 0.9040
# Epoch 88/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0172 - accuracy: 0.9930 - val_loss: 0.3866 - val_accuracy: 0.9040
# Epoch 89/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.3860 - val_accuracy: 0.9040
# Epoch 90/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0218 - accuracy: 0.9916 - val_loss: 0.3836 - val_accuracy: 0.9040
# Epoch 91/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0236 - accuracy: 0.9925 - val_loss: 0.3840 - val_accuracy: 0.9060
# Epoch 92/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 0.3841 - val_accuracy: 0.9060
# Epoch 93/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0226 - accuracy: 0.9925 - val_loss: 0.3855 - val_accuracy: 0.9060
# Epoch 94/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0183 - accuracy: 0.9949 - val_loss: 0.3861 - val_accuracy: 0.9020
# Epoch 95/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.3881 - val_accuracy: 0.9020
# Epoch 96/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0283 - accuracy: 0.9911 - val_loss: 0.3851 - val_accuracy: 0.9040
# Epoch 97/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0233 - accuracy: 0.9911 - val_loss: 0.3864 - val_accuracy: 0.9000
# Epoch 98/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 0.3841 - val_accuracy: 0.9000
# Epoch 99/100
# 34/34 [==============================] - 58s 2s/step - loss: 0.0228 - accuracy: 0.9916 - val_loss: 0.3855 - val_accuracy: 0.8980
# Epoch 100/100
# 34/34 [==============================] - 57s 2s/step - loss: 0.0219 - accuracy: 0.9944 - val_loss: 0.3890 - val_accuracy: 0.9000

# %%
# loss and validation loss
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.plot(h.history['loss'],color="#F7728B", label='loss')
plt.plot(h.history['val_loss'], color="#3CA3EC", label='validation loss')
plt.legend(loc="upper right",fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.title(label="Loss & Validation Loss")
# Out:
# Text(0.5, 1.0, 'Loss & Validation Loss')

# %%
# accuracy and validation accuracy
plt.figure(figsize=(20,8))
plt.plot(h.history['accuracy'],color="#51B232", label='accuracy')
plt.plot(h.history['val_accuracy'], color="#CF8F32", label='validation accuracy')
plt.legend(loc="upper right",fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.title(label="Accuracy & Validation Accuracy")
# Out:
# Text(0.5, 1.0, 'Accuracy & Validation Accuracy')

# %%
# test the model 
results = model.evaluate(X_test, Y_test, batch_size=64)
print('test loss',results[0], 'test acc:',results[1])
results
# Out:
# 660/660 [==============================] - 4s 6ms/step
# test loss 0.38203005409150415 test acc: 0.9045454263687134
# [0.38203005409150415, 0.9045454263687134]

# %%
# test the model
y_pred = model.predict(X_test, batch_size=64)
print(accuracy_score(np.argmax(Y_test, axis=1), np.argmax(y_pred, axis=1)))
# Out:
# 0.9045454545454545

# %%
y_pred[0], y_pred[0][0],y_pred[0][1], y_pred.type()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac11a41f9d3c> in <module>()
#       1 import numpy as np
#       2
# ----> 3 y_pred[0], y_pred[0][0],y_pred[0][1], y_pred.type()
#
# NameError: name 'y_pred' is not defined

# %%
#Confution Matrix

pred_results = np.where(y_pred>=0.5, 1,y_pred) 
pred_results2 = np.where(pred_results<0.5, 0,pred_results)

import sklearn
from sklearn.metrics import confusion_matrix
cm= sklearn.metrics.confusion_matrix(Y_test.argmax(axis=1), pred_results2.argmax(axis=1))
print(cm)
# Out:
# [[329  31]
#  [ 32 268]]

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(cm, annot=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0f9904d173b0> in <module>()
#       1 import seaborn as sn
#       2 import matplotlib.pyplot as plt
# ----> 3 sn.heatmap(cm, annot=True)
#       4 plt.show()
#
# NameError: name 'cm' is not defined

# %%
labels = ['benign', 'malignant']

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f01997b3dcc4> in <module>()
#       3 fig = plt.figure()
#       4 ax = fig.add_subplot(111)
# ----> 5 cax = ax.matshow(cm)
#       6 plt.title('Confusion matrix of the classifier')
#       7 fig.colorbar(cax)
#
# NameError: name 'cm' is not defined
